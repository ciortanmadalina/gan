# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x = np.random.uniform(0, 1, 10)
plt.ion()

# %%
plt.plot(np.random.uniform(0, 1, 10))
plt.show()

# %%
# %matplotlib notebook

# %%
fig1 = plt.figure()
plt.plot(x)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(x)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(np.random.uniform(0,1,6))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(np.random.uniform(0,1,6))

# %%
# %matplotlib inline
plt.figure()
plt.plot(np.random.uniform(0,1,6))

# %%
for i in range(3):
    plt.figure()
    plt.plot(np.random.uniform(0,1,6))

# %%
plt.figure()
for i in range(3):
    plt.plot(np.random.uniform(0,1,6))

# %%
# %matplotlib inline

# %%
# %matplotlib notebook
plt.figure()
for i in range(3):
    print("blah")
    plt.plot(np.random.uniform(0,1,6))
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
# blah
# blah
# blah

# %%
# %matplotlib inline
plt.figure()
for i in range(3):
    print("blah")
    plt.plot(np.random.uniform(0,1,6))
    plt.show()
# Out:
# blah
# blah
# blah

# %%
# %autocall 0
# Out:
# Automatic calling is: OFF

# %%
/print "blah" "azeaze" x
# Out:
# blah azeaze [ 0.16170101  0.90540408  0.39294596  0.62538574  0.70856775  0.29733422
#   0.54299914  0.33118911  0.33560844  0.98800371]

# %%
# %pdef plt.plot
# Out:
#  plt.plot(*args, **kwargs)

# %%
# ?plt.plot

# %%
# %%bash
# ls -al
# touch 'this'
# ls -al
# rm 'this'
# ls -al
# Out:
# Couldn't find program: 'bash'
